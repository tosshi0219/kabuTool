# %%
import pandas_datareader.data as web
from pandas_datareader.nasdaq_trader import get_nasdaq_symbols
from tqdm import tqdm

# %%
symbols = get_nasdaq_symbols()

# %%
symbols[symbols.index == 'NVDA']
# Out:
#         Nasdaq Traded                      Security Name Listing Exchange  \
# Symbol
# NVDA             True  NVIDIA Corporation - Common Stock                Q
#
#        Market Category    ETF  Round Lot Size  Test Issue Financial Status  \
# Symbol
# NVDA                 Q  False           100.0       False                N
#
#        CQS Symbol NASDAQ Symbol  NextShares
# Symbol
# NVDA          NaN          NVDA       False

# %%
symbols
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Listed Funds Trust AAF First Priority CLO Bond...
# AAAU             True                       Perth Mint Physical Gold ETF
# AACG             True  ATA Creativity Global - American Depositary Sh...
# AACQ             True     Artius Acquisition Inc. - Class A Common Stock
# AACQU            True  Artius Acquisition Inc. - Unit consisting of o...
# AACQW            True                  Artius Acquisition Inc. - Warrant
# AADR             True                AdvisorShares Dorsey Wright ADR ETF
# AAL              True       American Airlines Group, Inc. - Common Stock
# AAMC             True               Altisource Asset Management Corp Com
# AAME             True       Atlantic American Corporation - Common Stock
# ...

# %%
datum = web.DataReader("NVDA","yahoo","2019/1/1","2020/10/13")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,2))
plt.plot(datum.Close)
plt.show()

# %%
data = {}
error_symbols = []
for s in tqdm(symbols.index):
    try:
        data[s] = web.DataReader(s,"yahoo","2019/1/1")
    except:
        error_symbols.append(s)

# %% [markdown]
# ## ブログ用

# %%
import pandas_datareader.data as web
from pandas_datareader.nasdaq_trader import get_nasdaq_symbols
from tqdm import tqdm

symbols = get_nasdaq_symbols()

data = {}
error_symbols = []
for s in tqdm(symbols.index):
    try:
        data[s] = web.DataReader(s,"yahoo","2019/1/1")
    except:
        error_symbols.append(s)
